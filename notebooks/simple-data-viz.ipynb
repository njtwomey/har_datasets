# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as pl 
import seaborn as sns 
import pickle
from os.path import join, pardir

# %matplotlib inline

sns.set_context('paper')
sns.set_style('darkgrid')

pwd = join(pardir, 'data', 'raw', 'pamap2')
# pwd = join(pardir, 'data', 'raw', 'anguita2013')

# %%
def load(pwd, fname): 
    return pickle.load(open(join(pwd, f'{fname}.pkl'), 'rb'))

# %%
labels = load(pwd, 'labels')
folds = load(pwd, 'fold')
accel = load(pwd, 'accel-wrist')
accel.loc[:, 'mag'] = (accel.x ** 2 + accel.y ** 2 + accel.z ** 2).pow(0.5)
index = load(pwd, 'index')

print(labels.shape, folds.shape, accel.shape, index.shape)

accel.iloc[np.arange(2000) + 0*10000].plot()
# Out:
# (2872533,) (2872533, 1) (2872533, 4) (2872533, 3)
